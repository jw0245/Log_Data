# %%
import pandas as pd

file = open('./dataset/res_data.txt', 'rt', encoding='UTF8')

lines = file.readlines()

# %%
for i in range(0, 50, +1):
    print(lines[i])
# Out:
#  {"scope": "manage", "expires_in": "10000", "token_type": "Bearer", "access_token": "dfsjkldsfjkldsfjklsdfjsdfjfsddsdsfjsdfklsdfklsdfjdsflkj"}
#
#  {"scope": "manage", "expires_in": "300", "token_type": "Bearer", "access_token": "asdjklsadjlksadjlkasdasd"}
#
#  {"api_cnt": "5", "rsp_msg": "정상", "version": "v1", "api_list": [{"api_uri": "/v1/ginsu/apis"}, {"api_uri": "/v1/ginsu/consents"}, {"api_uri": "/v1/ginsu/insurances"}, {"api_uri": "/v1/ginsu/insurances/basic"}, {"api_uri": "/v1/ginsu/insurances/transactions"}], "rsp_code": "00000", "min_version": "v1"}
#
#  {"rsp_msg": "정상", "insu_cnt": "1", "rsp_code": "00000", "insu_list": [{"insu_num": "20210101010101", "insu_type": "20", "prod_name": "금보원보증보험", "is_consent": "true", "insu_status": "01"}], "search_timestamp": "20210210000000"}
#
# ...

# %% [markdown]
# ### 식별 및 활용 가능한 행찾기
